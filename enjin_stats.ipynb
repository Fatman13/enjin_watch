# %% [markdown]
# ### Run stats.py to aggregate data fist.

# %%
# %run -i 'stats.py'
# Out:
# Enjin Watch List: ['enjin_watch_200512_0202.csv', 'enjin_watch_200519_0201.csv', 'enjin_watch_200425_0203.csv', 'enjin_watch_200412_1603.csv', 'enjin_watch_200424_0202.csv', 'enjin_watch_200601_0201.csv', 'enjin_watch_200526_0201.csv', 'enjin_watch_200527_0201.csv', 'enjin_watch_200513_0201.csv', 'enjin_watch_200518_0202.csv', 'enjin_watch_200505_0202.csv', 'enjin_watch_200504_0203.csv', 'enjin_watch_200531_0202.csv', 'enjin_watch_200508_0201.csv', 'enjin_watch_200509_0201.csv', 'enjin_watch_200502_0202.csv', 'enjin_watch_200423_0204.csv', 'enjin_watch_200412_1700.csv', 'enjin_watch_200417_0205.csv', 'enjin_watch_200503_0205.csv', 'enjin_watch_200606_0201.csv', 'enjin_watch_200422_0202.csv', 'enjin_watch_200521_0201.csv', 'enjin_watch_200520_0201.csv', 'enjin_watch_200515_0201.csv', 'enjin_watch_200514_0201.csv', 'enjin_watch_200416_0202.csv', 'enjin_watch_200428_0202.csv', 'enjin_watch_200429_0202.csv', 'enjin_watch_200506_0202.csv', 'enjin_watch_200412_1455.csv', 'enjin_watch_20041
# ...

# %% [markdown]
# ### ENJ transaction amount againt date

# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.ticker import FuncFormatter
import glob, os

newest = max(glob.iglob('enjin_stats_*.csv'), key=os.path.getctime)
print(newest)

headers = ['date', 'date_m', 'type', 'amount']
df = pd.read_csv(newest)
print(df)
fig, ax = plt.subplots()
for key, grp in df.groupby(['type']):
    ax = grp.plot(ax=ax, kind='line', x='date', y='amount', label=key)
plt.gcf().autofmt_xdate()
# Out:
# enjin_stats_200606_1119.csv
#           date  date_m    type  status         amount
# 0   2020-05-23  200523   total     200   36895.213997
# 1   2020-05-23  200523  listed     200   30419.169998
# 2   2020-05-23  200523    sold     200    6476.043999
# 3   2020-05-24  200524   total     200  111675.095646
# 4   2020-05-24  200524  listed     200  106508.945647
# 5   2020-05-24  200524    sold     200    5166.149999
# 6   2020-05-25  200525   total     200  156105.717284
# 7   2020-05-25  200525  listed     200  154091.817284
# 8   2020-05-25  200525    sold     200    2013.900000
# 9   2020-05-26  200526   total     200   31244.030000
# 10  2020-05-26  200526  listed     200   22175.700000
# 11  2020-05-26  200526    sold     200    9068.330000
# 12  2020-05-27  200527   total     200   76610.999999
# 13  2020-05-27  200527  listed     200   60957.999999
# 14  2020-05-27  200527    sold     200   15653.000000
# 15  2020-05-28  200528   total     200  161717.899999
# ...
